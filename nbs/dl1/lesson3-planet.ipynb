# %% [markdown]
# ## Multi-label prediction with Planet Amazon dataset

# %%
# %%capture
from notebook import notebookapp
server = list(notebookapp.list_running_servers())[0]

if server['hostname'] == 'localhost':
  # Local environment
  # %reload_ext autoreload
  # %autoreload 2
  # %matplotlib inline
else:
  # Cloud
  # !pip install git+https://github.com/fastai/fastai.git
  # !curl https://course.fast.ai/setup/colab | bash

# %%
from fastai.vision import *
from fastai.utils.show_install import *
show_install()
# Out:
# ```text
# === Software ===
# python        : 3.6.8
# fastai        : 1.0.55.dev0
# fastprogress  : 0.1.21
# torch         : 1.1.0
# nvidia driver : 410.79
# torch cuda    : 10.0.130 / is available
# torch cudnn   : 7501 / is enabled
#
# === Hardware ===
# nvidia gpus   : 1
# torch devices : 1
#   - gpu0      : 15079MB | Tesla T4
#
# === Environment ===
# platform      : Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# distro        : #1 SMP Wed Dec 19 21:19:13 PST 2018
# conda env     : Unknown
# python        : /usr/bin/python3
# sys.path      :
# /env/python
# /usr/lib/python36.zip
# /usr/lib/python3.6
# /usr/lib/python3.6/lib-dynload
# /usr/local/lib/python3.6/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.6/dist-packages/IPython/extensions
# /root/.ipython
# ```
#
# Please make sure to include opening/closing ``` when you paste into forums/github to make the reports appear formatted as code sections.
#
# ...

# %% [markdown]
# ## Getting the data

# %% [markdown]
# The planet dataset isn't available on the [fastai dataset page](https://course.fast.ai/datasets) due to copyright restrictions. You can download it from Kaggle however. Let's see how to do this by using the [Kaggle API](https://github.com/Kaggle/kaggle-api) as it's going to be pretty useful to you if you want to join a competition or use other Kaggle datasets later on.
#
# First, install the Kaggle API by uncommenting the following line and executing it, or by executing it in your terminal (depending on your platform you may need to modify this slightly to either add `source activate fastai` or similar, or prefix `pip` with a path. Have a look at how `conda install` is called for your platform in the appropriate *Returning to work* section of https://course.fast.ai/. (Depending on your environment, you may also need to append "--user" to the command.)

# %%
! pip install kaggle --upgrade
# Out:
# Requirement already up-to-date: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.4)
# ...

# %% [markdown]
# Then you need to upload your credentials from Kaggle on your instance. Login to kaggle and click on your profile picture on the top left corner, then 'My account'. Scroll down until you find a button named 'Create New API Token' and click on it. This will trigger the download of a file named 'kaggle.json'.
#
# Upload this file to the directory this notebook is running in, by clicking "Upload" on your main Jupyter page, then uncomment and execute the next two commands (or run them in a terminal). For Windows, uncomment the last two commands.

# %%
! mkdir -p ~/.kaggle/
! mv kaggle.json ~/.kaggle/

# For Windows, uncomment these two commands
# ! mkdir %userprofile%\.kaggle
# ! move kaggle.json %userprofile%\.kaggle

# %% [markdown]
# Protect your token!

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# You're all set to download the data from [planet competition](https://www.kaggle.com/c/planet-understanding-the-amazon-from-space). You **first need to go to its main page and accept its rules**, and run the two cells below (uncomment the shell commands to download and unzip the data). If you get a `403 forbidden` error it means you haven't accepted the competition rules yet (you have to go to the competition page, click on *Rules* tab, and then scroll to the bottom to find the *accept* button).

# %%
path = Config.data_path()/'planet'
path.mkdir(parents=True, exist_ok=True)
path
# Out:
# PosixPath('/root/.fastai/data/planet')

# %%
! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train-jpg.tar.7z -p {path}  
! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train_v2.csv -p {path}  
! unzip -q -n {path}/train_v2.csv.zip -d {path}
# Out:
# ...
# 100% 598M/600M [00:03<00:00, 197MB/s]
# 100% 600M/600M [00:03<00:00, 195MB/s]
# ...
#   0% 0.00/159k [00:00<?, ?B/s]
# 100% 159k/159k [00:00<00:00, 54.8MB/s]

# %% [markdown]
# To extract the content of this file, we'll need 7zip, so uncomment the following line if you need to install it (or run `sudo apt install p7zip-full` in your terminal).

# %%
# ! conda install -y -c haasad eidl7zip
# ! sudo apt install p7zip-full

# %% [markdown]
# And now we can unpack the data (uncomment to run - this might take a few minutes to complete).

# %%
! 7za -bd -y -so x {path}/train-jpg.tar.7z | tar xf - -C {path.as_posix()}

# %% [markdown]
# ## Multiclassification

# %% [markdown]
# Contrary to the pets dataset studied in last lesson, here each picture can have multiple labels. If we take a look at the csv file containing the labels (in 'train_v2.csv' here) we see that each `image_name` is associated to several `tags` separated by spaces.

# %%
df = pd.read_csv(path/'train_v2.csv')
df.head()
# Out:
#   image_name                                       tags
# 0    train_0                               haze primary
# 1    train_1            agriculture clear primary water
# 2    train_2                              clear primary
# 3    train_3                              clear primary
# 4    train_4  agriculture clear habitation primary road

# %%
df.tail()
# Out:
#         image_name                                           tags
# 40474  train_40474                                  clear primary
# 40475  train_40475                                         cloudy
# 40476  train_40476                      agriculture clear primary
# 40477  train_40477                 agriculture clear primary road
# 40478  train_40478  agriculture cultivation partly_cloudy primary

# %% [markdown]
# To put this in a `DataBunch` while using the [**data block API**](https://docs.fast.ai/data_block.html#The-data-block-API), we need to use `ImageList` (and not `ImageDataBunch`). This will make sure the model has the proper loss function to deal with **multiple classes**.
#
# We define the transformations first, having into account the kind of images we have. By default we apply a random horizontal flip, and rotations. We add these:
# * `flip_vert`:  images can be vertically flipped or rotated by 90 degrees
# * `max_lighting`:  lightning and contrast changes will be applied with the indicated probability.
# * `max_zoom`:  adjust the maximum zoom applied
# * `max_warp`:  we disable warp because images are always taken with the same angle

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %% [markdown]
# Now we follow the usual steps detailed in the data block API:
# 1. Provide inputs
# 2. Split the data
# 3. Label the inputs
# 4. Apply transformations
# 5. Convert to a DataBunch
# 6. Apply normalization
#
# We use parentheses around the data block pipeline below, so that we can use a multiline statement without needing to add '\\'.
#
# We divide the whole process into two. First we get the label lists:

# %%
np.random.seed(42)
src = (ImageList.from_csv(path, 'train_v2.csv', folder='train-jpg', suffix='.jpg')
       .split_by_rand_pct(0.2)
       .label_from_df(cols='tags', label_delim=' '))

# %%
src
# Out:
# LabelLists;
#
# Train: LabelList (32384 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: MultiCategoryList
# haze;primary,clear;primary,clear;primary,haze;primary;water,agriculture;clear;cultivation;primary;water
# Path: /root/.fastai/data/planet;
#
# Valid: LabelList (8095 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: MultiCategoryList
# clear;primary;road,clear;primary;water,clear;conventional_mine;habitation;primary;road;water,cloudy,agriculture;clear;cultivation;cultivation;habitation;primary;road;water
# Path: /root/.fastai/data/planet;
#
# Test: None

# %% [markdown]
# Then we create the normalized ImageDataBunch:

# %%
data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (32384 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: MultiCategoryList
# haze;primary,clear;primary,clear;primary,haze;primary;water,agriculture;clear;cultivation;primary;water
# Path: /root/.fastai/data/planet;
#
# Valid: LabelList (8095 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: MultiCategoryList
# clear;primary;road,clear;primary;water,clear;conventional_mine;habitation;primary;road;water,cloudy,agriculture;clear;cultivation;cultivation;habitation;primary;road;water
# Path: /root/.fastai/data/planet;
#
# Test: None

# %% [markdown]
# The DataBunch's `show_batch` method still works, and show us the different labels separated by `;`.

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# To create a `Learner` we use the same function as in lesson 1. Our base architecture is resnet50 again, but the metrics are a little bit different: we use `accuracy_thresh` instead of `accuracy`. In lesson 1, we determined the prediction for a given class by picking the biggest final activation as the result, but here, each activation can be 0. or 1. `accuracy_thresh` selects the ones that are above a certain threshold (0.5 by default) and compares them to the ground truth. A 0.2 threshold works pretty well always.
#
# As for Fbeta, it's the metric that was used by Kaggle on this competition. Go [here](https://en.wikipedia.org/wiki/F1_score) for more details.
#
# We use `partial` (Python 3) for partial function application, basically when we want to apply always the same parameters to another function (wrapping).

# %%
arch = models.resnet50

# %%
help(accuracy_thresh)
# Out:
# Help on function accuracy_thresh in module fastai.metrics:
#
# accuracy_thresh(y_pred:torch.Tensor, y_true:torch.Tensor, thresh:float=0.5, sigmoid:bool=True) -> <function NewType.<locals>.new_type at 0x7f784b6c1f28>
#     Computes accuracy when `y_pred` and `y_true` are the same size.

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = cnn_learner(data, arch, metrics=[acc_02, f_score])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 97169514.71it/s]

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# We need to find the point with the steepest slope. So we can choose a leaning rate somewhere around 1e-2.

# %%
lr = 0.02

# %% [markdown]
# Then we can fit the head of our network.

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.124568</td>
#       <td>0.110167</td>
#       <td>0.953057</td>
#       <td>0.904302</td>
#       <td>02:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.117236</td>
#       <td>0.102596</td>
#       <td>0.956051</td>
#       <td>0.914646</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.107590</td>
#       <td>0.095906</td>
#       <td>0.957221</td>
#       <td>0.918814</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.097454</td>
#       <td>0.118973</td>
#       <td>0.957105</td>
#       <td>0.923600</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('stage-1-rn50')

# %% [markdown]
# ...And fine-tune the whole model:

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# We get a different shape now. For the initial layers we find a point when loss starts to go up, and choose 10 times less (so 1e-05). For the final layers we choose 5 or 10 times less that the LR chosen for 1st stage (was 1e-02), as a rule of thumb.

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.098620</td>
#       <td>0.583793</td>
#       <td>0.950841</td>
#       <td>0.918660</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.100691</td>
#       <td>0.110602</td>
#       <td>0.949424</td>
#       <td>0.919193</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.095523</td>
#       <td>0.168638</td>
#       <td>0.956059</td>
#       <td>0.923435</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.088682</td>
#       <td>0.147397</td>
#       <td>0.957708</td>
#       <td>0.927523</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('stage-2-rn50')

# %% [markdown]
# And now... we'll use **transfer learning**. We trained with 128x128 images, for speeding up the training but also to do transfer learning from our prior model knowledge to the original images (256x256). For the model it'll be a totally new dataset, and that will fix our possible overfitting, maybe improving our final accuracy.
#
# Thanks to data block API we'll only change one part of the original chain, assigning the new dataset to the prior learner.

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %% [markdown]
# We repeat the whole process over the same model using the new data!

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# We don't see a clear negative slope now. With this kind of shape we can take the point before it shoots up (5e-2), and choose something like 10 times less (5e-3). Or check 2e-4.

# %%
lr=5e-3

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.089761</td>
#       <td>0.130788</td>
#       <td>0.956822</td>
#       <td>0.925907</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.087448</td>
#       <td>0.196849</td>
#       <td>0.956647</td>
#       <td>0.924054</td>
#       <td>05:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.087810</td>
#       <td>0.126499</td>
#       <td>0.956611</td>
#       <td>0.929233</td>
#       <td>05:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.085387</td>
#       <td>0.188252</td>
#       <td>0.956807</td>
#       <td>0.928204</td>
#       <td>05:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('stage-1-256-rn50')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.084918</td>
#       <td>0.198144</td>
#       <td>0.958304</td>
#       <td>0.928051</td>
#       <td>07:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.084988</td>
#       <td>0.114560</td>
#       <td>0.957679</td>
#       <td>0.926846</td>
#       <td>07:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.082589</td>
#       <td>0.099227</td>
#       <td>0.958442</td>
#       <td>0.929823</td>
#       <td>07:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.080342</td>
#       <td>0.094601</td>
#       <td>0.959045</td>
#       <td>0.930038</td>
#       <td>07:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# Terrific result!!!

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-256-rn50')

# %% [markdown]
# You won't really know how you're going until you submit to Kaggle, since the leaderboard isn't using the same subset as we have for training. But as a guide, 50th place (out of 938 teams) on the private leaderboard was a score of `0.930`.

# %%
learn.export()

# %% [markdown]
# ## fin

# %% [markdown]
# (This section will be covered in part 2 - please don't ask about it just yet! :) )

# %%
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg.tar.7z | tar xf - -C {path}
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg-additional.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg-additional.tar.7z | tar xf - -C {path}

# %%
test = ImageList.from_folder(path/'test-jpg').add(ImageList.from_folder(path/'test-jpg-additional'))
len(test)
# Out:
# 61191

# %%
learn = load_learner(path, test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
thresh = 0.2
labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in preds]

# %%
labelled_preds[:5]
# Out:
# ['agriculture cultivation partly_cloudy primary road',
#  'clear haze primary water',
#  'agriculture clear cultivation primary',
#  'clear primary',
#  'partly_cloudy primary']

# %%
fnames = [f.name[:-4] for f in learn.data.test_ds.items]

# %%
df = pd.DataFrame({'image_name':fnames, 'tags':labelled_preds}, columns=['image_name', 'tags'])

# %%
df.to_csv(path/'submission.csv', index=False)

# %%
! kaggle competitions submit planet-understanding-the-amazon-from-space -f {path/'submission.csv'} -m "My submission"
# Out:
# ...
# 100%|██████████████████████████████████████| 2.18M/2.18M [00:02<00:00, 1.05MB/s]
# Successfully submitted to Planet: Understanding the Amazon from Space

# %% [markdown]
# Private Leaderboard score: 0.9296 (around 80th)
